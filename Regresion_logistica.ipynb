# %% [markdown]
# **Integrantes:**
#
# *   Jenniffer Karola Beltran Lopez
# *   Francisco Danilo Arteaga Guardado

# %% [markdown]
# **Algoritmo de regresión Logistica**

# %% [markdown]
# La regresión logística es un algoritmo de aprendizaje supervisado utilizado para estimar la probabilidad de que una variable objetivo categórica adquiera un valor específico basado en un conjunto de variables predictoras. Los resultados de la clasificación logística se suelen presentar mediante coeficientes, probabilidades y medidas de evaluación.

# %% [markdown]
# **Codigo fuente**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# Define a pipeline to search for the best combination of PCA truncation
# and classifier regularization.
pca = PCA()
# Define a Standard Scaler to normalize inputs
scaler = StandardScaler()

# set the tolerance to a large value to make the example faster
logistic = LogisticRegression(max_iter=10000, tol=0.1)
pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("logistic", logistic)])

X_digits, y_digits = datasets.load_digits(return_X_y=True)
# Parameters of pipelines can be set using '__' separated parameter names:
param_grid = {
    "pca__n_components": [5, 15, 30, 45, 60],
    "logistic__C": np.logspace(-4, 4, 4),
}
search = GridSearchCV(pipe, param_grid, n_jobs=2)
search.fit(X_digits, y_digits)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)

# Plot the PCA spectrum
pca.fit(X_digits)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(
    np.arange(1, pca.n_components_ + 1), pca.explained_variance_ratio_, "+", linewidth=2
)
ax0.set_ylabel("PCA explained variance ratio")

ax0.axvline(
    search.best_estimator_.named_steps["pca"].n_components,
    linestyle=":",
    label="n_components chosen",
)
ax0.legend(prop=dict(size=12))

# For each number of components, find the best classifier results
results = pd.DataFrame(search.cv_results_)
components_col = "param_pca__n_components"
best_clfs = results.groupby(components_col).apply(
    lambda g: g.nlargest(1, "mean_test_score")
)

best_clfs.plot(
    x=components_col, y="mean_test_score", yerr="std_test_score", legend=False, ax=ax1
)
ax1.set_ylabel("Classification accuracy (val)")
ax1.set_xlabel("n_components")

plt.xlim(-1, 70)

plt.tight_layout()
plt.show()
# Out:
# Best parameter (CV score=0.924):
# {'logistic__C': 0.046415888336127774, 'pca__n_components': 60}

# %% [markdown]
# **Explicación de resultados de la implementación del algoritmo**

# %% [markdown]
# Este algoritmo utiliza un pipeline con PCA y regresión logística para realizar la clasificación de dígitos manuscritos del conjunto de datos MNIST. Realiza una búsqueda exhaustiva de hiperparámetros para encontrar la mejor combinación de parámetros del modelo. Luego, muestra los resultados en gráficos que representan la varianza explicada por cada componente principal de PCA y la precisión de clasificación en función del número de componentes utilizados. Estos resultados permiten comprender cómo la reducción de dimensionalidad afecta el rendimiento de clasificación en este problema.
